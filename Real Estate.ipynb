# %%
# importing the libraries
import pandas as pd

# %%
# reading the dataset
df=pd.read_csv("C:\\Users\\kondu\\Downloads\\12.real state.csv")
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %% [markdown]
# # 1. Find city wise list all the villa which is not less than ten thousand

# %%
df[(df["type"]=="villa") & (df["price"]>=10000)][["city","type","price"]].sort_values(by=["city"])
# Out:
#                city   type   price
# 362        ANTELOPE  villa  115000
# 468          AUBURN  villa  260000
# 888    CAMERON PARK  villa  119000
# 383      CARMICHAEL  villa  139500
# 414      CARMICHAEL  villa  182000
# 94       CARMICHAEL  villa  250134
# 17   CITRUS HEIGHTS  villa  116250
# 158  CITRUS HEIGHTS  villa   69000
# 192       ELK GROVE  villa  145000
# 173       ELK GROVE  villa  100000
# 160       ELK GROVE  villa   71000
# 171       ELK GROVE  villa   98000
# 34        ELK GROVE  villa  141000
# 30        ELK GROVE  villa  133000
# 190       FAIR OAKS  villa  142500
# 248          FOLSOM  villa  240000
# 279      GOLD RIVER  villa  300000
# 934         LINCOLN  villa  188000
# 901         LINCOLN  villa  138000
# 8    RANCHO CORDOVA  villa   94905
# 704       ROSEVILLE  villa  212500
# 922       ROSEVILLE  villa  170000
# 390       ROSEVILLE  villa  150000
# 378       ROSEVILLE  villa  127000
# 814       ROSEVILLE  villa  350000
# 363       ROSEVILLE  villa  115000
# ...

# %% [markdown]
# # 2. In GALT city which residential type has more than 800sq__ft. Display their respective details street,sq__ft,sale_date,city.

# %%
df[(df["city"]=="GALT") & (df["sq__ft"]>800)][["street","city","type","sq__ft","sale_date"]].sort_values(by=["sq__ft"])
# Out:
#                   street  city         type  sq__ft  \
# 174   1121 CREEKSIDE WAY  GALT  Residential    1080
# 372         201 CARLO CT  GALT  Residential    1080
# 402  746 MOOSE CREEK WAY  GALT  Residential    1100
# 61      306 CAMELLIA WAY  GALT  Residential    1130
# 652        925 COBDEN CT  GALT  Residential    1140
# 409        332 PALIN AVE  GALT  Residential    1204
# 957     82 WILDFLOWER DR  GALT  Residential    1262
# 189      840 TRANQUIL LN  GALT  Residential    1266
# 55    1122 WILD POPPY CT  GALT  Residential    1406
# 63            404 6TH ST  GALT  Residential    1479
# 800     1214 DAWNWOOD DR  GALT  Residential    1548
# 439        913 COBDEN CT  GALT  Residential    1555
# 508      200 OAKWILDE ST  GALT  Residential    1606
# 968     1178 WARMWOOD CT  GALT  Residential    1770
# 454      709 CIMMARON CT  GALT  Residential    1798
# 480    1042 STARBROOK DR  GALT  Residential    1928
# 296    796 BUTTERCUP CIR  GALT  Residential    2159
# ...

# %% [markdown]
# # 3. Which is the cheapest Villa in CA. name the city,street and price for the villa

# %%
df[df["type"]=="villa"][["city","street","type","price"]].sort_values(by=["price"],ascending=True).head(1)
# Out:
#            city           street   type  price
# 335  SACRAMENTO  5840 WALERGA RD  villa  40000

# %% [markdown]
# # 4. List top 5 residency details which lie in the budget of 60000-120000, an area more than 1450, min bedroom 3 and, min bathroom 2.

# %%
df["budget"]=df["price"].between(60000,120000,inclusive=True)
# Out:
# C:\Users\kondu\AppData\Local\Temp\ipykernel_1336\2302239969.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df["budget"]=df["price"].between(60000,120000,inclusive=True)

# %%
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
df[(df["sq__ft"]>1450) & (df["beds"]>=3) & (df["baths"]>=2) & (df["budget"]==True)]
# Out:
#            street        city    zip state  beds  baths  sq__ft          type  \
# 366  7342 GIGI PL  SACRAMENTO  95828    CA     4      4    1995  Multi-Family
#
#                         sale_date   price   latitude   longitude  budget
# 366  Mon May 19 00:00:00 EDT 2008  120000  38.490704 -121.410176    True

# %% [markdown]
# # 5. separate list of residential apartments with more than 2 beds. Also include columns in following order City,Baths,Sq_feet,Price,flat_type,Beds respectively.

# %%
resi_apart_morethan_2beds=df[(df["type"]=="Residential") & (df["beds"]>2)][["city","sq__ft","type","baths","beds","price"]]

# %%
resi_apart_morethan_2beds
# Out:
#                 city  sq__ft         type  baths  beds   price
# 1         SACRAMENTO    1167  Residential      1     3   68212
# 6         SACRAMENTO    1104  Residential      2     3   90895
# 7         SACRAMENTO    1177  Residential      1     3   91002
# 9          RIO LINDA    1146  Residential      2     3   98937
# 10        SACRAMENTO     909  Residential      2     3  100309
# ..               ...     ...          ...    ...   ...     ...
# 980       SACRAMENTO    2280  Residential      3     4  232425
# 981       SACRAMENTO    1477  Residential      2     3  234000
# 982   CITRUS HEIGHTS    1216  Residential      2     3  235000
# 983        ELK GROVE    1685  Residential      2     4  235301
# 984  EL DORADO HILLS    1362  Residential      2     3  235738
#
# [715 rows x 6 columns]
